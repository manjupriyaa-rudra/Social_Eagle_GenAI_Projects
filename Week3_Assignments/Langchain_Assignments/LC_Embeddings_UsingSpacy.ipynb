# %%
# ---------------------------
# LC using other free methods
# ---------------------------

# %%
# !pip install spacy
# Out:
# ...
#    ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/15.3 MB 15.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.9/15.3 MB 12.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.9/15.3 MB 12.4 MB/s eta 0:00:01
#    ------------ --------------------------- 4.7/15.3 MB 5.5 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.3 MB 5.5 MB/s eta 0:00:02
#    ------------------- -------------------- 7.3/15.3 MB 5.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.7/15.3 MB 5.7 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.3 MB 5.5 MB/s eta 0:00:02
#    --------------------------- ------------ 10.5/15.3 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 11.5/15.3 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 12.3/15.3 MB 5.2 MB/s eta 0:00:01
# ...

# %%
import spacy

loadModel = spacy.load("en_core_web_md")

# %%
strValue = loadModel("Using free models for embeddings")

# %%
print(strValue.vector[:3])
# Out:
# [-0.77665603  0.1559078   0.25460598]

# %%
print(len(strValue.vector))
# Out:
# 300
